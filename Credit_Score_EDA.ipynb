# %% [markdown]
# # Exploratory Data Analysis In Python - Credit Score

# %% [markdown]
# ## Introduction
# ### What is Exploratory Data Analysis ?
#
# Exploratory Data Analysis or (EDA) is understanding the data sets by summarizing their main characteristics often plotting them visually. This step is very important especially when we arrive at modeling the data in order to apply Machine learning. Plotting in EDA consists of Histograms, Box plot, Scatter plot and many more. It often takes much time to explore the data. Through the process of EDA, we can ask to define the problem statement or definition on our data set which is very important.
#
# ### How to perform Exploratory Data Analysis ?
#
# The answer is it depends on the data set that you are working. There is no one method or common methods in order to perform EDA.
#
# ### What data are we exploring ?
#
# The Credit Score dataset exist in Kaggle and it uses for Machine learning since it has two separated dataset for test and train.
# The data-set can be downloaded from [here](https://www.kaggle.com/datasets/parisrohan/credit-score-classification).
#
# To give a piece of brief information about the data set this data contains more of 100, 000 rows and 30 columns which contains Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_dateNum_of_Delayed_Payment	Changed_Credit_Limit	Num_Credit_Inquiries	Credit_Mix	Outstanding_Debt, Credit_Score etc,. We will perform EDA on train dataset.

# %% [markdown]
# ## 1. Importing the Required Libraries for EDA

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes = True)

# %% [markdown]
# ## 2. Loading and generating Data Frame using Pandas

# %% [markdown]
# To preparing the Credit Score Database for EDA analysis, loading the data into the pandas data frame is certainly one of the most important step, the value from the data set is comma-separated. So all we have to do is to just read the CSV into a data frame and pandas data frame does the job for us.

# %%
df = pd.read_csv("train.csv", low_memory = False)
#Displaying top 5 rows
df.head()
# Out:
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
# 3      19114.12                    NaN                  3  ...        Good
# 4      19114.12            1824.843333                  3  ...        Good
#
# ...

# %%
# diplaying last 5 rows
df.tail()
# Out:
#             ID Customer_ID   Month   Name Age          SSN Occupation  \
# 99995  0x25fe9  CUS_0x942c   April  Nicks  25  078-73-5990   Mechanic
# 99996  0x25fea  CUS_0x942c     May  Nicks  25  078-73-5990   Mechanic
# 99997  0x25feb  CUS_0x942c    June  Nicks  25  078-73-5990   Mechanic
# 99998  0x25fec  CUS_0x942c    July  Nicks  25  078-73-5990   Mechanic
# 99999  0x25fed  CUS_0x942c  August  Nicks  25  078-73-5990   Mechanic
#
#       Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 99995      39628.99            3359.415833                  4  ...
# 99996      39628.99            3359.415833                  4  ...
# 99997      39628.99            3359.415833                  4  ...
# 99998      39628.99            3359.415833                  4  ...
# 99999     39628.99_            3359.415833                  4  ...
#
#        Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  \
# 99995           _            502.38                34.663572
# ...

# %%
df.shape
# Out:
# (100000, 28)

# %% [markdown]
# # 3. Checking Data Types
# In this part we are checking the datatypes and if some of them are not the one that it should be, we will change it.

# %%
# Identifying each column data type
df.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Month                        object
# Name                         object
# Age                          object
# SSN                          object
# Occupation                   object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                  object
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit         object
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# ...

# %% [markdown]
# # 4. Dropping Irrelevant Columns
# This step is certainly needed in every EDA because sometimes there would be many columns that we never use in such cases dropping is the only solution. In this case, we only keep the most important columns like Customer_ID, Annual_Income, Num_Bank_Accounts_ Num_of_Loan, Num_of_Delayed_Payment, Credit_History_Age and Credit_Score. We could work on different columns based on what project we want to implement or what information stakeholders need. However in this project we only want to explore the whole schema of the credit score for 1, 000, 000 rows and we want to get the most important attributes and work on them.

# %%
df = df.drop(['ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation', 'Monthly_Inhand_Salary', 'Num_Credit_Card', 'Interest_Rate',
         'Type_of_Loan', 'Delay_from_due_date', 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix',
         'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Payment_of_Min_Amount', 'Total_EMI_per_month',
         'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance'], axis = 1)
df.head()
# Out:
#   Customer_ID Annual_Income  Num_Bank_Accounts Num_of_Loan  \
# 0   CUS_0xd40      19114.12                  3           4
# 1   CUS_0xd40      19114.12                  3           4
# 2   CUS_0xd40      19114.12                  3           4
# 3   CUS_0xd40      19114.12                  3           4
# 4   CUS_0xd40      19114.12                  3           4
#
#   Num_of_Delayed_Payment     Credit_History_Age Credit_Score
# 0                      7  22 Years and 1 Months         Good
# 1                    NaN                    NaN         Good
# 2                      7  22 Years and 3 Months         Good
# 3                      4  22 Years and 4 Months         Good
# 4                    NaN  22 Years and 5 Months         Good

# %% [markdown]
# #### Here we could rename the column name to move forward with EDA. However in this dataset there is no need to change any of columns name.

# %% [markdown]
# # 5. Dropping the Duplicate rows
# This is often a handy thing to do because a huge data set as in this case contains more than 1,000, 000 rows often have some duplicate data which might be disturbing, so here I remove all the duplicate value from the data-set.

# %%
duplicate_rows = df[df.duplicated()]
print ("number of duplicate rows: ", duplicate_rows)
# Out:
# number of duplicate rows:        Customer_ID Annual_Income  Num_Bank_Accounts Num_of_Loan  \
# 45     CUS_0x95ee      73928.46                  4           0
# 156    CUS_0x4100      19300.34                  6           5
# 206    CUS_0x4d43      20787.69                  8           3
# 623    CUS_0x6856     129067.59                  1           4
# 750    CUS_0x28b5      23404.86                  6           0
# ...           ...           ...                ...         ...
# 99205  CUS_0x5e3f      33137.28                  7           9
# 99335  CUS_0x4bff       56341.2                  8           3
# 99494  CUS_0x290c      28954.04                  8           5
# 99753  CUS_0x4a8f      34493.92                  9           7
# 99975   CUS_0xf16      16680.35                  1           4
#
#       Num_of_Delayed_Payment Credit_History_Age Credit_Score
# 45                         7                NaN         Good
# ...

# %%
df.count()
# Out:
# Customer_ID               100000
# Annual_Income             100000
# Num_Bank_Accounts         100000
# Num_of_Loan               100000
# Num_of_Delayed_Payment     92998
# Credit_History_Age         90970
# Credit_Score              100000
# dtype: int64

# %% [markdown]
# ##### Now let's remove the duplicate values

# %%
df = df.drop_duplicates()
df.head()
# Out:
#   Customer_ID Annual_Income  Num_Bank_Accounts Num_of_Loan  \
# 0   CUS_0xd40      19114.12                  3           4
# 1   CUS_0xd40      19114.12                  3           4
# 2   CUS_0xd40      19114.12                  3           4
# 3   CUS_0xd40      19114.12                  3           4
# 4   CUS_0xd40      19114.12                  3           4
#
#   Num_of_Delayed_Payment     Credit_History_Age Credit_Score
# 0                      7  22 Years and 1 Months         Good
# 1                    NaN                    NaN         Good
# 2                      7  22 Years and 3 Months         Good
# 3                      4  22 Years and 4 Months         Good
# 4                    NaN  22 Years and 5 Months         Good

# %%
df.count()
# Out:
# Customer_ID               99506
# Annual_Income             99506
# Num_Bank_Accounts         99506
# Num_of_Loan               99506
# Num_of_Delayed_Payment    92510
# Credit_History_Age        90970
# Credit_Score              99506
# dtype: int64

# %% [markdown]
# # 6. Replacing Invalid Values
# Some values have invalid values in our cell or have extra characters. As we are mainly dealing with numerical data, in this case, we will replace some characters to make invalid data valid and maintain precious data for our analysis. For instance, by skimming through "annual_income", "num_bank_account", and "num_of_loan", we could see some fields have extra "_" characters that we are going to remove.

# %%
df = df.replace({'Annual_Income': {'_': None, '-': None, ' ': None}}, regex=True)
df = df.replace({'Num_Bank_Accounts': {'_': None, '-': None, ' ': None}}, regex=True)
df = df.replace({'Num_of_Loan': {'_': '', '-': '', ' ': ''}}, regex=True)
df = df.replace({'Num_of_Delayed_Payment': {'_': None, '-': None, ' ': None}}, regex=True)

# %% [markdown]
# #### We could also use: df = df.replace(r'[^\w\s]|_', '', regex=True)

# %%
df.dtypes
# Out:
# Customer_ID               object
# Annual_Income             object
# Num_Bank_Accounts          int64
# Num_of_Loan               object
# Num_of_Delayed_Payment    object
# Credit_History_Age        object
# Credit_Score              object
# dtype: object

# %%
df[['Annual_Income', 'Num_Bank_Accounts', 'Num_of_Loan', 'Num_of_Delayed_Payment']] = df[['Annual_Income', 'Num_Bank_Accounts', 'Num_of_Loan', 'Num_of_Delayed_Payment']].apply(pd.to_numeric)

# %% [markdown]
# #### No we want to change the Credit_History_Age to numeric (since it looks like: 22 Years and 1 Months)

# %%
df['Credit_History_Age'] = df['Credit_History_Age'].str[:2]
df[['Credit_History_Age']] = df[['Credit_History_Age']].apply(pd.to_numeric)
print(df['Credit_History_Age'])
# Out:
# 0        22.0
# 1         NaN
# 2        22.0
# 3        22.0
# 4        22.0
#          ...
# 99995    31.0
# 99996    31.0
# 99997    31.0
# 99998    31.0
# 99999    31.0
# Name: Credit_History_Age, Length: 99506, dtype: float64

# %%
df['Credit_History_Age'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# # 7. Dropping missing or NULLs and NaNs
# This is mostly similar to the previous step but in here all the missing values are detected and are dropped later. Now, this is not a good approach to do so, because many people just replace the missing values with the mean or the average of that column, but here due to existing of big dataset we could drop them.

# %%
df.count()
# Out:
# Customer_ID               99506
# Annual_Income             92531
# Num_Bank_Accounts         99506
# Num_of_Loan               99506
# Num_of_Delayed_Payment    89144
# Credit_History_Age        90970
# Credit_Score              99506
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Customer_ID                   0
# Annual_Income              6975
# Num_Bank_Accounts             0
# Num_of_Loan                   0
# Num_of_Delayed_Payment    10362
# Credit_History_Age         8536
# Credit_Score                  0
# dtype: int64

# %%
df = df.dropna()
df.count()
# Out:
# Customer_ID               75874
# Annual_Income             75874
# Num_Bank_Accounts         75874
# Num_of_Loan               75874
# Num_of_Delayed_Payment    75874
# Credit_History_Age        75874
# Credit_Score              75874
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Customer_ID               0
# Annual_Income             0
# Num_Bank_Accounts         0
# Num_of_Loan               0
# Num_of_Delayed_Payment    0
# Credit_History_Age        0
# Credit_Score              0
# dtype: int64

# %% [markdown]
# # 8. Detecting Outliers
# An outlier is a point or set of points that are different from other points. Sometimes they can be very high or very low. It's often a good idea to detect and remove the outliers. Because outliers are one of the primary reasons for resulting in a less accurate model. Hence it's a good idea to remove them. The outlier detection and removing that I am going to perform is called IQR score technique. Often outliers can be seen with visualizations using a box plot. Herein all the plots, you can find some points are outside the box they are none other than outliers. The technique of finding and removing outlier that I am performing in this assignment is taken help of a tutorial from [towards data science](https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba).

# %%
sns.boxplot(x=df['Annual_Income'])
# Out:
# <AxesSubplot:xlabel='Annual_Income'>

# %%
sns.boxplot(x=df['Num_Bank_Accounts'])
# Out:
# <AxesSubplot:xlabel='Num_Bank_Accounts'>

# %%
sns.boxplot(x=df['Num_of_Loan'])
# Out:
# <AxesSubplot:xlabel='Num_of_Loan'>

# %%
sns.boxplot(x=df['Num_of_Delayed_Payment'])
# Out:
# <AxesSubplot:xlabel='Num_of_Delayed_Payment'>

# %%
sns.boxplot(x=df['Credit_History_Age'])
# Out:
# <AxesSubplot:xlabel='Credit_History_Age'>

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Annual_Income             53212.58375
# Num_Bank_Accounts             3.00000
# Num_of_Loan                   4.00000
# Num_of_Delayed_Payment        9.00000
# Credit_History_Age           13.00000
# dtype: float64

# %% [markdown]
# #### Now we are going to remove outliers

# %%
df.shape
# Out:
# (75874, 7)

# %%
df = df[~((df < (Q1 - 1.5*IQR)) | (df > (Q3 + 1.5*IQR))).any(axis = 1)]
df.shape
# Out:
# (69103, 7)

# %% [markdown]
# As seen above there were around 8,600 rows were outliers. But you cannot completely remove the outliers because even after you use the above technique there maybe 1–2 outlier unremoved but that ok because there were more than 100 outliers. Something is better than nothing.
#
# At the end we could realize that in the dataset almost 30% of data was invalid and outliers.

# %% [markdown]
# # 9. Describing the Clean Dataset

# %%
df.describe()
# Out:
#        Annual_Income  Num_Bank_Accounts   Num_of_Loan  Num_of_Delayed_Payment  \
# count   69103.000000       69103.000000  69103.000000            69103.000000
# mean    48239.463318           5.442325      3.580756               13.555200
# std     35067.447934           2.575052      2.451997                6.166246
# min      7005.930000           0.000000      0.000000                0.000000
# 25%     19168.835000           4.000000      2.000000                9.000000
# 50%     36338.780000           6.000000      3.000000               14.000000
# 75%     69740.960000           7.000000      5.000000               18.000000
# max    152340.560000          11.000000      9.000000               28.000000
#
#        Credit_History_Age
# count        69103.000000
# mean            17.803294
# std              8.319242
# min              0.000000
# 25%             11.000000
# 50%             18.000000
# 75%             24.000000
# max             33.000000

# %%
df.shape
# Out:
# (69103, 7)

# %%
df.describe()
# Out:
#        Annual_Income  Num_Bank_Accounts   Num_of_Loan  Num_of_Delayed_Payment  \
# count   69103.000000       69103.000000  69103.000000            69103.000000
# mean    48239.463318           5.442325      3.580756               13.555200
# std     35067.447934           2.575052      2.451997                6.166246
# min      7005.930000           0.000000      0.000000                0.000000
# 25%     19168.835000           4.000000      2.000000                9.000000
# 50%     36338.780000           6.000000      3.000000               14.000000
# 75%     69740.960000           7.000000      5.000000               18.000000
# max    152340.560000          11.000000      9.000000               28.000000
#
#        Credit_History_Age
# count        69103.000000
# mean            17.803294
# std              8.319242
# min              0.000000
# 25%             11.000000
# 50%             18.000000
# 75%             24.000000
# max             33.000000

# %% [markdown]
# #### Now we could see all of values are valid

# %% [markdown]
# # 10. Plot Features -Scatter, and Histogram

# %% [markdown]
# ### Histogram

# %% [markdown]
# Histogram refers to the frequency of occurrence of variables in an interval. In this case, we have 3 types of credits, Good, Standard, Poor we we wnat compare these three categorical data. To do this histogram is one of the trivial solutions which lets us know the total number credit score group population.

# %%
sns.countplot(x=df['Credit_Score'])
# Out:
# <AxesSubplot:xlabel='Credit_Score', ylabel='count'>

# %% [markdown]
# #### We could make the histogram with annual income too, so it gives us good summary of the income related to credit score

# %%
df.Annual_Income.value_counts().nlargest(10).plot(kind='bar', figsize=(10,5))
plt.title("Annual Income")
plt.ylabel('Number of People in the Category')
plt.xlabel('Income Groups');

# %% [markdown]
# #### We want to make heat map and other plots to better understand the relationship between features. To do that we are going to assign numeric values to credit scroe, thus, we assign 1 for poor, 2 for standard and 3 for good credit score.

# %%
df['Credit_Score'] = df['Credit_Score'].str.replace('Good', '3', n=-1)
df['Credit_Score'] = df['Credit_Score'].str.replace('Standard', '2', n=-1)
df['Credit_Score'] = df['Credit_Score'].str.replace('Poor', '1', n=-1)
df['Credit_Score'] = df[['Credit_Score']].apply(pd.to_numeric)
df.dtypes
# Out:
# Customer_ID                object
# Annual_Income             float64
# Num_Bank_Accounts           int64
# Num_of_Loan                 int64
# Num_of_Delayed_Payment    float64
# Credit_History_Age        float64
# Credit_Score                int64
# dtype: object

# %%
df.head()
# Out:
#   Customer_ID  Annual_Income  Num_Bank_Accounts  Num_of_Loan  \
# 0   CUS_0xd40       19114.12                  3            4
# 2   CUS_0xd40       19114.12                  3            4
# 3   CUS_0xd40       19114.12                  3            4
# 5   CUS_0xd40       19114.12                  3            4
# 8  CUS_0x21b1       34847.84                  2            1
#
#    Num_of_Delayed_Payment  Credit_History_Age  Credit_Score
# 0                     7.0                22.0             3
# 2                     7.0                22.0             3
# 3                     4.0                22.0             3
# 5                     4.0                22.0             3
# 8                     4.0                26.0             2

# %% [markdown]
# ### Heat Maps

# %% [markdown]
# Heat Maps is a type of plot which is necessary when we need to find the dependent variables. One of the best way to find the relationship between the features can be done using heat maps.

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#                         Annual_Income  Num_Bank_Accounts  Num_of_Loan  \
# Annual_Income                1.000000          -0.252325    -0.245239
# Num_Bank_Accounts           -0.252325           1.000000     0.469013
# Num_of_Loan                 -0.245239           0.469013     1.000000
# Num_of_Delayed_Payment      -0.243368           0.592874     0.469406
# Credit_History_Age           0.258797          -0.478243    -0.606776
# Credit_Score                 0.201365          -0.387444    -0.357264
#
#                         Num_of_Delayed_Payment  Credit_History_Age  \
# Annual_Income                        -0.243368            0.258797
# Num_Bank_Accounts                     0.592874           -0.478243
# Num_of_Loan                           0.469406           -0.606776
# Num_of_Delayed_Payment                1.000000           -0.476195
# Credit_History_Age                   -0.476195            1.000000
# Credit_Score                         -0.368343            0.388192
#
# ...

# %% [markdown]
# #### In the HEAT MAP we could see that Credit_Score depends mainly on the Credit_History_Age and has a negative relationship with Num_Bank_Account, Num_of_Delayed_Payment and Num_of_Loan.
#
# #### However, we expect it should have negative relationship with our three features, we didn't know the comparison of the relationships.

# %%
fig, axes = plt.subplots(2, 2)
sns.set(rc = {'figure.figsize':(12,12)})

#create boxplot in each subplot
sns.boxplot(data=df, x='Credit_Score', y='Credit_History_Age', ax=axes[0,0])
sns.boxplot(data=df, x='Credit_Score', y='Num_Bank_Accounts', ax=axes[0,1])
sns.boxplot(data=df, x='Credit_Score', y='Num_of_Loan', ax=axes[1,0])
sns.boxplot(data=df, x='Credit_Score', y='Num_of_Delayed_Payment', ax=axes[1,1])
# Out:
# <AxesSubplot:xlabel='Credit_Score', ylabel='Num_of_Delayed_Payment'>

# %% [markdown]
# ### Strip Plot

# %%
sns.stripplot(x='Credit_History_Age', y='Num_Bank_Accounts', data=df)
# Out:
# <AxesSubplot:xlabel='Credit_History_Age', ylabel='Num_Bank_Accounts'>

# %% [markdown]
# ### Pair Plot

# %%
sns.pairplot(df,hue = None, diag_kind ='kde', palette = 'RED')
plt.show()

# %%
# !jupyter nbconvert --to html --basic classic --execute --embed-images Credit_Score_EDA.ipynb
